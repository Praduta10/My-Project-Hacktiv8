# %% [markdown]
# # INTRODUCING
#
# Nama : Praduta Firman Anugrah
#
# Graded Challenged-1
#
# Dataset yang digunakan adalah csv, yang dimana pada data tersebut berisikan 721 pokemon, dengan nomor, type 1 dan 2, dan status dasar sebagai berikut : HP (health points), Sp.Atk(kekuatan spesial), Sp.Def(kekuatan bertahan spesial) dan Speed(kecepatan). Pada dataset tersebut akan dicari yang manakah pokemon terbaik berdasarkan status dasar, dan apakah ada pengaruh antara pokemon yang memiliki 1 type dengan pokemon yang memiliki 2 type.

# %% [markdown]
# # IMPORT PUSTAKA

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # DATA LOADING

# %%
df = pd.read_csv('Pokemon.csv')

# %% [markdown]
# INFORMASI DATA DASAR

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# Dataset pokemon berisi 800 baris dan 13 kolom.

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.sample(10)
# Out:
#        #               Name   Type 1   Type 2  Total  HP  Attack  Defense  \
# 747  678     MeowsticFemale  Psychic      NaN    466  74      48       76
# 528  476          Probopass     Rock    Steel    525  60      55      145
# 791  715            Noivern   Flying   Dragon    535  85      70       80
# 438  393             Piplup    Water      NaN    314  53      51       53
# 110  102          Exeggcute    Grass  Psychic    325  60      40       80
# 675  614            Beartic      Ice      NaN    485  95     110       80
# 329  303  MawileMega Mawile    Steel    Fairy    480  50     105      125
# 148  137            Porygon   Normal      NaN    395  65      60       70
# 153  142         Aerodactyl     Rock   Flying    515  80     105       65
# 331  305             Lairon    Steel     Rock    430  60      90      140
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 747       83       81    104           6      False
# ...

# %% [markdown]
# Mengeksplorasi data dari 10 sampel random dari dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 66.5+ KB

# %% [markdown]
# Dari data info di atas dapat dilihat bahwa, kolom Type 2 terdapat banyak data yang kosong. Dikarenakan sebab tidak semua jenis pokemon memiliki 2 type.

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df.columns = df.columns.str.upper()
df.head()
# Out:
#    #                   NAME TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.drop(["GENERATION" ,"#"], axis = 1, inplace = True)
df.head()
# Out:
#                     NAME TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    SP. DEF  SPEED  LEGENDARY
# 0       65     45      False
# 1       80     60      False
# 2      100     80      False
# 3      120     80      False
# 4       50     65      False

# %%
df.set_index("NAME", inplace = True)
df.head()
# Out:
#                       TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        SP. DEF  SPEED  LEGENDARY
# NAME
# Bulbasaur                   65     45      False
# Ivysaur                     80     60      False
# Venusaur                   100     80      False
# VenusaurMega Venusaur      120     80      False
# Charmander                  50     65      False

# %%
df.index = df.index.str.replace(".*(?=Mega)","")
df.head()
# Out:
# <ipython-input-15-64d9215a58a4>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace(".*(?=Mega)","")
#               TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur      Grass  Poison    318  45      49       49       65       65
# Ivysaur        Grass  Poison    405  60      62       63       80       80
# Venusaur       Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# Charmander      Fire     NaN    309  39      52       43       60       50
#
#                SPEED  LEGENDARY
# NAME
# Bulbasaur         45      False
# Ivysaur           60      False
# Venusaur          80      False
# Mega Venusaur     80      False
# Charmander        65      False

# %%
data_type2_dengan_catatan = df.copy()
data_type2_dengan_catatan["TYPE 2"].fillna(value = "None", inplace = True)
data_type2_dengan_catatan.head()
# Out:
#               TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur      Grass  Poison    318  45      49       49       65       65
# Ivysaur        Grass  Poison    405  60      62       63       80       80
# Venusaur       Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# Charmander      Fire    None    309  39      52       43       60       50
#
#                SPEED  LEGENDARY
# NAME
# Bulbasaur         45      False
# Ivysaur           60      False
# Venusaur          80      False
# Mega Venusaur     80      False
# Charmander        65      False

# %% [markdown]
# Mengganti semua kolom dengan huruf besar, menghilangkan GENERATION dan #, menghilangkan prefix sebelum kata Mega, mengganti kolom nama menjadi index, dan mengganti isi "NaN" dengan "None" yang dapat diartikan tidak mempunyai tipe ke 2. Atau hanya memnpunyai 1 tipe saja pokemon tersebut.

# %% [markdown]
# # MISSING VALUE

# %% [markdown]
# 1.Mencari dulu data atau nilai yang kosong, nilai yang bersifat integer tapi dikolom string dan sebagainya.
# 2.Cara melihatnya adalah dengan isnull lalu sum dan mengisinya dengan fillna
# 3.Dibuat perintah baru supaya pada tabel yang dibuat tidak mengubah isi tabel yang akan dibuat.

# %%
df.isnull().sum()
# Out:
# TYPE 1         0
# TYPE 2       386
# TOTAL          0
# HP             0
# ATTACK         0
# DEFENSE        0
# SP. ATK        0
# SP. DEF        0
# SPEED          0
# LEGENDARY      0
# dtype: int64

# %%
mis = df.copy()

# %%
mis["TYPE 2"].fillna(value ="-", inplace = True)

# %%
mis.isnull().sum()
# Out:
# TYPE 1       0
# TYPE 2       0
# TOTAL        0
# HP           0
# ATTACK       0
# DEFENSE      0
# SP. ATK      0
# SP. DEF      0
# SPEED        0
# LEGENDARY    0
# dtype: int64

# %% [markdown]
# # DATA QUERY

# %%
df
# Out:
#                       TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# Mega Venusaur          Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
# ...                      ...     ...    ...  ..     ...      ...      ...
# Diancie                 Rock   Fairy    600  50     100      150      100
# Mega Diancie            Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined  Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound   Psychic    Dark    680  80     160       60      170
# Volcanion               Fire   Water    600  80     110      120      130
#
#                      SP. DEF  SPEED  LEGENDARY
# NAME
# ...

# %%
df[df["LEGENDARY"] == True]
# Out:
#                        TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Articuno                  Ice    Flying    580   90      85      100       95
# Zapdos               Electric    Flying    580   90      90       85      125
# Moltres                  Fire    Flying    580   90     100       90      125
# Mewtwo                Psychic       NaN    680  106     110       90      154
# Mega Mewtwo X         Psychic  Fighting    780  106     190      100      154
# ...                       ...       ...    ...  ...     ...      ...      ...
# Diancie                  Rock     Fairy    600   50     100      150      100
# Mega Diancie             Rock     Fairy    700   50     160      110      160
# HoopaHoopa Confined   Psychic     Ghost    600   80     110       60      150
# HoopaHoopa Unbound    Psychic      Dark    680   80     160       60      170
# Volcanion                Fire     Water    600   80     110      120      130
#
# ...

# %% [markdown]
# Berdasarkan data berarti terdapat 65 pokemon legendaris.
#
# Selanjutnya kita akan melihat data pokemon legenda yang mempunyai dual type dan total basic status lebih dari 700.

# %%
df[
    (df["LEGENDARY"] == True) &
    (df["TYPE 2"].notnull()) &
    (df["TOTAL"] > 700)]
# Out:
#                         TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  \
# NAME
# Mega Mewtwo X          Psychic  Fighting    780  106     190      100
# GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# Mega Rayquaza           Dragon    Flying    780  105     180      100
#
#                        SP. ATK  SP. DEF  SPEED  LEGENDARY
# NAME
# Mega Mewtwo X              154      100    130       True
# GroudonPrimal Groudon      150       90     90       True
# Mega Rayquaza              180      100    115       True

# %% [markdown]
# Kemudian untuk data pokemon yang mempunyai 1 tipe dan total basic status lebih dari 700.

# %%
df[
    (df["LEGENDARY"] == True) &
    (df["TYPE 2"].isnull()) &
    (df["TOTAL"] > 700)]
# Out:
#                       TYPE 1 TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Mega Mewtwo Y        Psychic    NaN    780  106     150       70      194
# KyogrePrimal Kyogre    Water    NaN    770  100     150       90      180
# Arceus                Normal    NaN    720  120     120      120      120
#
#                      SP. DEF  SPEED  LEGENDARY
# NAME
# Mega Mewtwo Y            120    140       True
# KyogrePrimal Kyogre      160     90       True
# Arceus                   120    120       True

# %% [markdown]
# Kemudian kita lihat data pokemon yang tidak legendary yang memiliki 2 tipe dan total basic status kurang dari 200.

# %%
df[
    (df["LEGENDARY"] == False) &
    (df["TYPE 2"].notnull()) &
    (df["TOTAL"] < 200)]
# Out:
#           TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  SPEED  \
# NAME
# Weedle       Bug  Poison    195  40      35       30       20       20     50
# Ralts    Psychic   Fairy    198  28      25       25       45       35     40
# Azurill   Normal   Fairy    190  50      20       40       20       40     20
#
#          LEGENDARY
# NAME
# Weedle       False
# Ralts        False
# Azurill      False

# %%
Kemudain kita lihat data pokemon yang memiliki 2 tipe dengan defense lebih dari 60 dan total basic status lebih dari 300

# %%
df[
    (df["TYPE 1"].notnull()) &
    (df["TYPE 2"].notnull()) &
    (df["TOTAL"] >= 300) &
    (df["DEFENSE"] >= 60)]
# Out:
#                       TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# Mega Venusaur          Grass  Poison    625  80     100      123      122
# Charizard               Fire  Flying    534  78      84       78      109
# Mega Charizard X        Fire  Dragon    634  78     130      111      130
# ...                      ...     ...    ...  ..     ...      ...      ...
# Diancie                 Rock   Fairy    600  50     100      150      100
# Mega Diancie            Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined  Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound   Psychic    Dark    680  80     160       60      170
# Volcanion               Fire   Water    600  80     110      120      130
#
#                      SP. DEF  SPEED  LEGENDARY
# NAME
# ...

# %% [markdown]
# # GROUPING & AGGREGATING

# %% [markdown]
# Kita akan melihat pokemon dengan type 1 dan juga yang dengan type 2 dengan total basic status

# %%
df.groupby(["TYPE 1","TYPE 2"])["TOTAL"].sum()
# Out:
# TYPE 1  TYPE 2
# Bug     Electric     791
#         Fighting    1100
#         Fire         910
#         Flying      5873
#         Ghost        236
#                     ...
# Water   Ice         1535
#         Poison      1280
#         Psychic     2405
#         Rock        1715
#         Steel        530
# Name: TOTAL, Length: 136, dtype: int64

# %% [markdown]
# Kemudian kita melihat gabungan 2 kolom type 2 dan legendary dengan status legendary adalah true, attack > 100 dan defense > 80

# %%
df[
    (df["LEGENDARY"] == True) &
    (df["ATTACK"] > 100) &
    (df["DEFENSE"] > 80)
].groupby(["TYPE 2","LEGENDARY"])["TOTAL"].count()
# Out:
# TYPE 2    LEGENDARY
# Dragon    True         3
# Electric  True         1
# Fairy     True         1
# Fighting  True         2
# Fire      True         2
# Flying    True         6
# Ice       True         3
# Psychic   True         1
# Water     True         1
# Name: TOTAL, dtype: int64

# %% [markdown]
# Berikutnya saya akan menampilkan gabungan 2 kolom type 1 dan legendary dengan status legendary adalah false, speed > 50 dan defense < 100

# %%
df[
    (df["LEGENDARY"] == False) &
    (df["DEFENSE"] < 100) &
    (df["SPEED"] > 50)
].groupby(["TYPE 2", "LEGENDARY"])["TOTAL"].count()
# Out:
# TYPE 2    LEGENDARY
# Bug       False         2
# Dark      False        14
# Dragon    False         8
# Electric  False         4
# Fairy     False         8
# Fighting  False        17
# Fire      False         7
# Flying    False        69
# Ghost     False         5
# Grass     False         7
# Ground    False        12
# Ice       False         6
# Normal    False         4
# Poison    False        20
# Psychic   False        14
# Rock      False         1
# Steel     False         7
# Water     False         4
# Name: TOTAL, dtype: int64

# %% [markdown]
# # EKSPLORASI DATA
#
# Dari dataset pokemon berikut ini akan kita dapat ketahui bahwa :
#
# Pokemon yang memiliki attack tertinggi adalah:

# %%
df[df["ATTACK"] == df["ATTACK"].max()]
# Out:
#                 TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Mega Mewtwo X  Psychic  Fighting    780  106     190      100      154
#
#                SP. DEF  SPEED  LEGENDARY
# NAME
# Mega Mewtwo X      100    130       True

# %% [markdown]
# Pokemon yang memiliki defense tertinggi adalah:

# %%
df[df["DEFENSE"] == df["DEFENSE"].max()]
# Out:
#              TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Mega Steelix  Steel  Ground    610  75     125      230       55       95
# Shuckle         Bug    Rock    505  20      10      230       10      230
# Mega Aggron   Steel     NaN    630  70     140      230       60       80
#
#               SPEED  LEGENDARY
# NAME
# Mega Steelix     30      False
# Shuckle           5      False
# Mega Aggron      50      False

# %% [markdown]
# Pokemon yang memiliki HP (health poin) tertinggi adalah:

# %%
df[df["HP"] == df["HP"].max()]
# Out:
#          TYPE 1 TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  SPEED  \
# NAME
# Blissey  Normal    NaN    540  255      10       10       75      135     55
#
#          LEGENDARY
# NAME
# Blissey      False

# %% [markdown]
# Pokemon yang memiliki Speed tertinggi adalah:

# %%
df[df["SPEED"] == df["SPEED"].max()]
# Out:
#                     TYPE 1 TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# DeoxysSpeed Forme  Psychic    NaN    600  50      95       90       95
#
#                    SP. DEF  SPEED  LEGENDARY
# NAME
# DeoxysSpeed Forme       90    180       True

# %% [markdown]
# Pokemon yang memiliki Total basic status tertinggi adalah :

# %%
df[df["TOTAL"] == df["TOTAL"].max()]
# Out:
#                 TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Mega Mewtwo X  Psychic  Fighting    780  106     190      100      154
# Mega Mewtwo Y  Psychic       NaN    780  106     150       70      194
# Mega Rayquaza   Dragon    Flying    780  105     180      100      180
#
#                SP. DEF  SPEED  LEGENDARY
# NAME
# Mega Mewtwo X      100    130       True
# Mega Mewtwo Y      120    140       True
# Mega Rayquaza      100    115       True

# %% [markdown]
# Ada berapa macamkah type pokemon di kolom TYPE 1?

# %%
print("Berikut ini adalah type pokemon di TYPE 1:\n", df["TYPE 1"].unique())
print("\nTotal type pokemon: ", df["TYPE 1"].nunique())
print("\nJumlah tiap type:\n ", df["TYPE 1"].value_counts())
print("\nDilihat dalam grafik\n")
df["TYPE 1"].value_counts().head(18).plot(kind = "bar")
# Out:
# Berikut ini adalah type pokemon di TYPE 1:
#  ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']
#
# Total type pokemon:  18
#
# Jumlah tiap type:
#   Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: TYPE 1, dtype: int64
#
# Dilihat dalam grafik
# <AxesSubplot:>

# %% [markdown]
# Ada berapa macamkah type pokemon di kolom TYPE 2?

# %%
print("Berikut ini adalah type pokemon di TYPE 2:\n", df["TYPE 2"].unique())
print("\nTotal type pokemon: ", df["TYPE 2"].nunique())
print("\nJumlah tiap type:\n ", df["TYPE 2"].value_counts())
print("\nDilihat dalam grafik\n")
df["TYPE 2"].value_counts().head(18).plot(kind = "bar")
# Out:
# Berikut ini adalah type pokemon di TYPE 2:
#  ['Poison' nan 'Flying' 'Dragon' 'Ground' 'Fairy' 'Grass' 'Fighting'
#  'Psychic' 'Steel' 'Ice' 'Rock' 'Dark' 'Water' 'Electric' 'Fire' 'Ghost'
#  'Bug' 'Normal']
#
# Total type pokemon:  18
#
# Jumlah tiap type:
#   Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Ghost       14
# Ice         14
# Water       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: TYPE 2, dtype: int64
#
# Dilihat dalam grafik
# <AxesSubplot:>

# %% [markdown]
# Saya akan membuat kolom baru di data dengan isinya adalah pokemon dengan type 1 & type 2

# %%
df["TYPE1&2"] = df["TYPE 1"] + "&" + df["TYPE 2"]
df.head()
# Out:
#               TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur      Grass  Poison    318  45      49       49       65       65
# Ivysaur        Grass  Poison    405  60      62       63       80       80
# Venusaur       Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  Grass  Poison    625  80     100      123      122      120
# Charmander      Fire     NaN    309  39      52       43       60       50
#
#                SPEED  LEGENDARY       TYPE1&2
# NAME
# Bulbasaur         45      False  Grass&Poison
# Ivysaur           60      False  Grass&Poison
# Venusaur          80      False  Grass&Poison
# Mega Venusaur     80      False  Grass&Poison
# Charmander        65      False           NaN

# %% [markdown]
# Ada berapa macamkah pokemon yang memiliki type 1 dan type 2?

# %%
print("\nTotal type 1 dan 2 pokemon: ", df["TYPE1&2"].nunique())
print("\nJumlah tiap typenya:\n", df["TYPE1&2"].value_counts())
print("\nDilihat dalam grafik\n")
df["TYPE1&2"].value_counts().head(18).plot(kind = "bar")
# Out:
# Total type 1 dan 2 pokemon:  136
#
# Jumlah tiap typenya:
#  Normal&Flying    24
# Grass&Poison     15
# Bug&Flying       14
# Bug&Poison       12
# Water&Ground     10
#                  ..
# Steel&Flying      1
# Poison&Dragon     1
# Normal&Ground     1
# Dragon&Fire       1
# Normal&Water      1
# Name: TYPE1&2, Length: 136, dtype: int64
#
# Dilihat dalam grafik
# <AxesSubplot:>

# %% [markdown]
# Dari Type manakah Pokemon Legend Terkuat yang berasal dari type 1?

# %%
legend_pokemon = df[
    (df["LEGENDARY"] == True) &
    (df["TOTAL"] > 700)]
legend_pokemon["TYPE 1"].value_counts().head(5).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dari Type manakah Pokemon Non Legend Terkuat yang berasal dari type 2?

# %%
nonlegend_pokemon = df[
    (df["LEGENDARY"] == False) &
    (df["TOTAL"] > 500)]
nonlegend_pokemon["TYPE 1"].value_counts().head(5).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # KESIMPULAN
#
# Dengan analisis dan eksplorasi data yang dilakukan, akan didapatkan hasil sebagai berikut :
#
# 1.Dari data diatas dapat disimpulkan bahwa pokemon dengan Mega evolution yaitu Mega MewTwo X, Mega MewTwo Y, dan Mega Rayquaza adalah pokemon dengan basic status tertinggi, dengan pokemon tertingginya adalah Mega Mewtwo X dengan attack tertinggi.
#
# 2.Lalu kemudian ada pokemon yang memiliki defense tertinggi adalah Mega Steelix, Shuckle, dan Mega Aggron.Kemudian pokemon dengan HP tertinggi adalah Blissey dan pokemon dengan Speed tertinggi adalah Deoxys Speed Forme.
#
# 3.Selanjutnya tipe pokemon di kolom TYPE 1 yang paling banyak adalah pokemon tipe Water dengan jumlah 112 pokemon.
#
# 4.Tipe pokemon di kolom TYPE 2 yang paling banyak adalah pokemon tipe Flying dengan jumlah 97 pokemon.
#
# 5.Dan yang terakhir adalah tipe pokemon yang dibuat dengan kolom baru dengan penggabungan TYPE1 & 2 yang paling banyak adalah pokemon tipe Normal & Flying dengan jumlah 24 pokemon.
